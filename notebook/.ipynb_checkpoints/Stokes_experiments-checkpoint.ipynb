# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.sparse.linalg as spla
import scipy.io as sio
import meshio
import dolfin as dl

import localpsfcpp as lpsf

# %%
vertices = np.loadtxt('mesh_vertices.txt')
cells = np.loadtxt('mesh_cells.txt', dtype=int)
dof_coords = np.loadtxt('dof_coords.txt')
vertex_in_dof = np.loadtxt('vertex_in_dof.txt', dtype=int)
dof_in_vertex = np.loadtxt('dof_in_vertex.txt', dtype=int)

mesh_meshio = meshio.Mesh(vertices, [("triangle", cells)])
mesh_meshio.write("mesh.xml")
mesh = dl.Mesh("mesh.xml")
dl.plot(mesh)
# Out:
# WARNING:root:DOLFIN XML is a legacy format. Consider using XDMF instead.
# [<matplotlib.lines.Line2D at 0x7f3a85421a30>,
#  <matplotlib.lines.Line2D at 0x7f3a85421d90>]

# %%
Hdgn_array = np.loadtxt('Hdgn_array.txt')
sqrtR = sio.loadmat('sqrtR_matrix.mat')['sqrtR']
M = sio.loadmat('mass_matrix.mat')['M']
diag_M = np.loadtxt('mass_matrix_diagonal.txt')

apply_Hdgn = lambda x: np.dot(Hdgn_array, x)
apply_HdgnT = lambda x: np.dot(Hdgn_array, x)
apply_M = lambda x: M * x
solve_M = spla.factorized(M)
apply_ML = lambda x: x * diag_M
solve_ML = lambda x: x / diag_M

# %%
V = dl.FunctionSpace(mesh, 'CG', 1)

err_dof_coords = np.linalg.norm(dof_coords - V.tabulate_dof_coordinates()) / np.linalg.norm(V.tabulate_dof_coordinates())
print('err_dof_coords=', err_dof_coords)
# Out:
# err_dof_coords= 0.0

# %%
kk = list(np.linspace(0,V.dim()-1,10,dtype=int))
for k in kk:
    ek = np.zeros(V.dim())
    ek[k] = 1.0
    psi_k = dl.Function(V)
    psi_k.vector()[:] = solve_ML(apply_Hdgn(solve_ML(ek)))

    plt.figure()
    cm = dl.plot(psi_k)
    plt.colorbar(cm)

# %%
dof_in_vertex[cells]
# cells
# Out:
# array([[  10,   11,   12],
#        [  10,   14,   13],
#        [  10,   12,   13],
#        ...,
#        [ 319,  318, 1396],
#        [ 530,  532,  506],
#        [ 298,  299,  588]])

# %%
err_reorder = np.linalg.norm(dof_coords - vertices[dof_in_vertex,:]) / np.linalg.norm(dof_coords)
print('err_reorder=', err_reorder)

vertices_dof_order = np.array(vertices[dof_in_vertex,:].T, order='C')
# cells_dof_order    = np.array(cells[dof_in_vertex,:].T,    order='C') # BAD
cells_dof_order    = np.array(vertex_in_dof[cells].T,    order='C') # GOOD
# Out:
# err_reorder= 0.0

# %%
vol, mu, Sigma = lpsf.compute_impulse_response_moments(apply_HdgnT, solve_ML, vertices_dof_order)
# Out:
# computing V
# computing mu
# ii = 0
# ii = 1
# computing Sigma
# ii = 0, jj = 0
# ii = 1, jj = 0
# ii = 1, jj = 1
# processing V
# processing mu
# processing Sigma
# done computing moments

# %%
from matplotlib.patches import Ellipse

def plot_ellipse(mu, Sigma, n_std_tau, ax=None, **kwargs):
    # Usage:
    #   https://github.com/NickAlger/nalger_helper_functions/tree/master/jupyter_notebooks/plot_ellipse.ipynb
    if ax is None:
        ax = plt.gca()

    ee, V = np.linalg.eigh(Sigma)
    e_big = ee[1]
    e_small = ee[0]
    v_big = V[:, 1]
    theta = np.arctan(v_big[1] / v_big[0]) * 180. / np.pi

    long_length = n_std_tau * 2. * np.sqrt(e_big)
    short_length = n_std_tau * 2. * np.sqrt(e_small)

    if not ('facecolor' in kwargs):
        kwargs['facecolor'] = 'none'

    if not ('edgecolor' in kwargs):
        kwargs['edgecolor'] = 'k'

    ellipse = Ellipse(mu, width=long_length, height=short_length, angle=theta, **kwargs)
    ax.add_artist(ellipse)

# %%
tau = 3.0

kk = list(np.linspace(0,V.dim()-1,10,dtype=int))
for k in kk:
    ek = np.zeros(V.dim())
    ek[k] = 1.0
    psi_k = dl.Function(V)
    psi_k.vector()[:] = solve_ML(apply_Hdgn(solve_ML(ek)))

    plt.figure()
    cm = dl.plot(psi_k)
    plt.colorbar(cm)
    plt.plot(mu[k][0], mu[k][1], '.k')
    plot_ellipse(mu[k], Sigma[k], tau, edgecolor='k')
    plt.plot(vertices_dof_order[0,k], vertices_dof_order[1,k], '.r')

# %%
num_neighbors = 10
min_vol_rtol = 1e-5
num_initial_batches = 5

lpsf_kernel = lpsf.create_LPSFKernel(apply_Hdgn, apply_HdgnT, apply_ML, apply_ML, solve_ML, solve_ML, 
                                    vertices_dof_order, vertices_dof_order, cells_dof_order, 
                                    tau, num_neighbors, min_vol_rtol, num_initial_batches)
# Out:
# computing V
# computing mu
# ii = 0
# ii = 1
# computing Sigma
# ii = 0, jj = 0
# ii = 1, jj = 0
# ii = 1, jj = 1
# processing V
# processing mu
# processing Sigma
# done computing moments
# computing impulse response batch
# computing impulse response batch
# computing impulse response batch
# computing impulse response batch
# computing impulse response batch

# %%
for b in range(len(lpsf_kernel.eta_batches)):
    eta_b = dl.Function(V)
    eta_b.vector()[:] = lpsf_kernel.eta_batches[b]

    plt.figure()
    cm = dl.plot(eta_b)
    plt.colorbar(cm)
    for ind in lpsf_kernel.dirac_ind_batches[b]:
        plt.plot(mu[ind][0], mu[ind][1], '.k')
        plot_ellipse(mu[ind], Sigma[ind], tau, edgecolor='k')
        plt.plot(vertices_dof_order[0,ind], vertices_dof_order[1,ind], '.r')

# %%
lpsf_kernel.dirac_kdtree.query(np.array([-1.1, 2.3]), 5)
# Out:
# (array([[ 31],
#         [ 34],
#         [ 27],
#         [166],
#         [ 83]], dtype=int32),
#  array([[297708.81505712],
#         [358472.20433549],
#         [370080.8394858 ],
#         [586944.55213724],
#         [590960.37102954]]))

# %%
Ker_array = ( 1.0 / diag_M.reshape((-1,1)) ) * (Hdgn_array / diag_M.reshape((1,-1)))

num_entries = 7
row_inds = list(np.random.randint(0, V.dim(), num_entries))
# col_inds = list(np.random.randint(0, V.dim(), num_entries))
col_inds = row_inds

for ii, jj in zip(row_inds, col_inds):
    value = lpsf_kernel.kernel_entry_LMDI(ii,jj)
#     value_true = Hdgn_array[ii,jj] / (diag_M[ii]*diag_M[jj])
    value_true = Ker_array[ii,jj]

    print('ii=', ii, ', jj=', jj, ', value=', value, ', value_true=', value_true)
# Out:
# ii= 1351 , jj= 1351 , value= 7.9929451141014e-06 , value_true= 7.992393823060882e-06
# ii= 1312 , jj= 1312 , value= 1.1419273376946121e-08 , value_true= 3.556092082807274e-08
# ii= 823 , jj= 823 , value= 1.7885067691967048e-05 , value_true= 1.8007554943149693e-05
# ii= 1127 , jj= 1127 , value= 7.222948719857602e-09 , value_true= 7.194722252631547e-09
# ii= 1344 , jj= 1344 , value= 1.8923036441801336e-08 , value_true= 2.2507519492090674e-08
# ii= 238 , jj= 238 , value= 2.1815997645865515e-08 , value_true= 3.347905362391914e-08
# ii= 1158 , jj= 1158 , value= 3.3974496906522437e-05 , value_true= 3.397388056188517e-05

# %%
rows = list(np.arange(50))
cols = list(np.arange(50))

B = lpsf_kernel.kernel_block_LMDI(rows, cols)
B_true = Ker_array[np.ix_(rows, cols)]

err_B = np.linalg.norm(B_true - B) / np.linalg.norm(B_true)
print('err_B=', err_B)
# Out:
# err_B= 0.18274358865928259

# %%
plt.figure()
plt.matshow(np.abs(B))
plt.colorbar()

plt.figure()
plt.matshow(np.abs(B_true))
plt.colorbar()

# %%
lpsf_kernel.num_neighbors = 5

kk = list(np.linspace(0,V.dim()-1,10,dtype=int))
for k in kk:
    plt.figure()
    psi_k = dl.Function(V)
    psi_k.vector()[:] = Ker_array[:,k].copy()

    plt.figure()
    cm = dl.plot(psi_k)
    plt.colorbar(cm)
    plt.title('psi '+str(k))

    psi_k_lpsf = dl.Function(V)
    psi_k_lpsf.vector()[:] = lpsf_kernel.kernel_block_LMDI(list(np.arange(V.dim())), [k]).reshape(-1).copy()

    plt.figure()
    cm = dl.plot(psi_k_lpsf)
    plt.colorbar(cm)
    plt.title('psi_lpsf '+str(k))
# Out:
# /tmp/ipykernel_588143/1490101152.py:17: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %%
bad_psi_vec = lpsf_kernel.kernel_block_LMDI(list(np.arange(V.dim())), [1415]).reshape(-1).copy()

print(np.any(np.isinf(bad_psi_vec)))
print(np.any(np.isnan(bad_psi_vec)))
# Out:
# False
# False

# %%
bad_psi_vec
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#        9.97680921e-10, 4.36096602e-09, 1.35331122e-07])

# %%
np.linalg.norm(psi_k_lpsf.vector()[:] - psi_k.vector()[:]) / np.linalg.norm(psi_k.vector()[:])
# Out:
# 0.012366061492502519

# %%
lpsf_kernel.dirac_inds
# Out:
# [0,
#  24,
#  36,
#  46,
#  70,
#  102,
#  104,
#  141,
#  184,
#  194,
#  201,
#  221,
#  240,
#  251,
#  315,
#  330,
#  395,
#  405,
#  418,
#  419,
#  486,
#  513,
#  547,
#  582,
#  589,
#  640,
#  655,
#  666,
#  678,
#  691,
#  706,
#  726,
#  815,
#  833,
#  844,
#  869,
#  914,
#  936,
#  1015,
#  1028,
#  1035,
#  1100,
#  1133,
#  1207,
#  1215,
#  1226,
#  1237,
#  1306,
#  1321,
#  1342,
#  1351,
#  1386,
#  1406,
#  1211,
#  172,
#  1317,
#  467,
#  864,
#  701,
#  931,
#  198,
#  1202,
#  42,
#  373,
#  19,
#  1390,
#  1362,
#  1330,
#  1047,
#  1073,
#  1292,
#  743,
#  1128,
#  483,
#  696,
#  527,
#  360,
#  1107,
#  674,
#  341,
#  118,
#  765,
#  225,
#  895,
#  56,
#  855,
#  489,
#  557,
#  1188,
#  320,
#  99,
#  1282,
#  1415,
#  7,
#  107,
#  635,
#  586,
#  209,
#  753,
#  168,
#  1125,
#  1254,
#  323,
#  1383,
#  1087,
#  861,
#  1069,
#  133,
#  114,
#  904,
#  1272,
#  464,
#  400,
#  885,
#  821,
#  1096,
#  595,
#  1384,
#  11,
#  927,
#  67,
#  442,
#  1081,
#  567,
#  260,
#  1296,
#  811,
#  434,
#  776,
#  377,
#  728,
#  58,
#  979,
#  1378,
#  242,
#  749,
#  1279,
#  416,
#  1214,
#  231,
#  476,
#  125,
#  1126,
#  818,
#  179,
#  17,
#  1123,
#  1345,
#  740,
#  334,
#  1229,
#  1154,
#  647,
#  459,
#  561,
#  152,
#  939,
#  999,
#  54,
#  792,
#  658,
#  653,
#  697,
#  608,
#  103,
#  298,
#  899,
#  236,
#  1221,
#  575,
#  479,
#  1209,
#  1086,
#  1026,
#  244,
#  1405,
#  756,
#  5,
#  51,
#  83,
#  1308,
#  1158,
#  267,
#  945,
#  695,
#  1316,
#  438,
#  130,
#  879,
#  215,
#  1343,
#  473,
#  925,
#  802,
#  625,
#  538,
#  813,
#  189,
#  1295,
#  66,
#  601,
#  347,
#  1103,
#  613]

# %%
lpsf_kernel.kernel_block_LMDI(list(np.arange(V.dim())), [0]).reshape(-1)
# Out:
# array([4.44212237e-08, 2.36030115e-08, 2.50309975e-08, ...,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00])

# %%
lpsf_kernel.kernel_block_LMDI(list(np.arange(V.dim())), [100]).reshape(-1)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
print(np.any(np.isnan(lpsf_kernel.mu)))
print(np.any(np.isinf(lpsf_kernel.mu)))
# Out:
# False
# False

# %%
for eta in lpsf_kernel.eta_batches:
    print(np.any(np.isnan(eta)))
    print(np.any(np.isinf(eta)))
    print()
# Out:
# False
# False
#
# False
# False
#
# False
# False
#
# False
# False
#
# False
# False

# %%
np.sum(np.logical_not(lpsf_kernel.Sigma_is_good))
# Out:
# 10

# %%
np.sum(np.array(lpsf_kernel.vol) == 0)
# Out:
# 0
