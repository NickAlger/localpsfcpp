# %%
import numpy as np
import scipy.linalg as sla
import matplotlib.pyplot as plt
from time import time

import localpsfcpp as lpsf

# %%
from nalger_helper_functions import plot_ellipse
# Out:
# KDTree not loaded
# AABBTree not loaded
# SimplexMesh not loaded
# geometric_sort not loaded
# brent_minimize not loaded
# ellipsoids_intersect not loaded
# EllipsoidBatchPicker not loaded

# %%
nx = 10
ny = 10
scaling_factor = 0.01
tau = 1.3
min_vol_rtol = 0.2

X, Y = np.meshgrid(np.linspace(0,1,nx), np.linspace(0,1,nx))
pp = np.vstack([X.reshape(-1), Y.reshape(-1)])
num_ellipsoids = pp.shape[1]
all_vol = list(np.random.rand(num_ellipsoids))
all_mu = list(pp.T)
# all_mu = [np.random.rand(2) for _ in range(num_ellipsoids)]
all_Sigma = list()
for k in range(num_ellipsoids):
    S0 = np.random.randn(2,2)
    all_Sigma.append(scaling_factor * sla.sqrtm(np.dot(S0.T, S0)))

all_points = all_mu
    
for k in range(num_ellipsoids):
    plot_ellipse(all_mu[k], all_Sigma[k], tau)
    plt.plot(all_points[k][0], all_points[k][1], '.k')
    
plt.xlim(-0.25, 1.25)
plt.ylim(-0.25, 1.25)
# Out:
# (-0.25, 1.25)

# %%
# EF = lpsf.EllipsoidForest(all_points, all_vol, all_mu, all_Sigma, tau)
EF = lpsf.EllipsoidForest(all_vol, all_mu, all_Sigma, tau)

# %%
batches = [[]]
squared_distances = list(-1.0 * np.ones(len(all_points)))

new_batch, squared_distances = EF.pick_ellipsoid_batch(batches, squared_distances, all_points, min_vol_rtol)
while new_batch:
    batches.append(new_batch)
    plt.figure()
    for b_old in batches[:-1]:
        for ind_old in b_old:
            plt.plot(all_points[ind_old][0], all_points[ind_old][1], '.r')
    
    for ind in new_batch:
        plot_ellipse(all_mu[ind], all_Sigma[ind], tau)
        plt.plot(all_points[ind][0], all_points[ind][1], '.k')

    plt.xlim(-0.25, 1.25)
    plt.ylim(-0.25, 1.25)
    
    new_batch, squared_distances = EF.pick_ellipsoid_batch(batches, squared_distances, all_points, min_vol_rtol)
    

big_vol_inds = (np.array(all_vol) > (min_vol_rtol * np.max(all_vol)))
plt.figure()
plt.plot(np.array(all_points)[big_vol_inds,0], np.array(all_points)[big_vol_inds,1], '.b')
plt.title('big_vol_inds')
plt.xlim(-0.25, 1.25)
plt.ylim(-0.25, 1.25)
# Out:
# (-0.25, 1.25)

# %%
num_ellipsoids = 10000
scaling_factor = 0.005
tau = 1.3
all_mu = [np.random.rand(2) for _ in range(num_ellipsoids)]
all_Sigma = list()
for k in range(num_ellipsoids):
    S0 = np.random.randn(2,2)
    all_Sigma.append(scaling_factor * sla.sqrtm(np.dot(S0.T, S0)))

all_points = all_mu
all_vol = list(np.random.rand(num_ellipsoids))

t = time()
EF = lpsf.EllipsoidForest(all_vol, all_mu, all_Sigma, tau)
dt_build = time() - t
print('num_ellipsoids=', num_ellipsoids, ', dt_build=', dt_build)

batches = [[]]
squared_distances = list(-1.0 * np.ones(len(all_points)))
t = time()
for k in range(25):
    new_batch, squared_distances = EF.pick_ellipsoid_batch(batches, squared_distances, all_points, min_vol_rtol)
    batches.append(new_batch)
dt_batches = time() - t
print('num_ellipsoids=', num_ellipsoids, ', dt_batches=', dt_batches)
# Out:
# num_ellipsoids= 10000 , dt_build= 0.04703164100646973
# num_ellipsoids= 10000 , dt_batches= 0.7703197002410889
